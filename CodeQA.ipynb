# %%
import pandas as pd
import numpy as np

# %%
reivews_df = pd.read_csv("./data/reivews_df.csv")
reivews_df
# Out:
#                                         id  \
# 0     f2e05937-ed94-4b6d-bb97-655692634ec2
# 1     15eb22a1-2245-4aad-9ba7-97df39c84f38
# 2     e17da92e-9603-46ca-8875-bb0e2b947aeb
# 3     96b4e922-b21b-49a0-8db5-32c3ddf34ecf
# 4     b31c6eef-6585-446a-be66-30a96ba8b77c
# 5     a1ef1419-ca84-4b0f-b1dc-4c14a6678d26
# 6     8737810a-2147-4c54-9ccb-6e43f9eeefbc
# 7     b2e95359-7897-4579-bfc6-04d18079ecbb
# 8     c84b4dc1-518b-45f9-9149-ed51402584b0
# 9     cdfa19dc-ad50-45c6-be3c-bafd916f9de4
# 10    b0703312-3de9-43af-b2dd-f7f1ebc638bf
# 11    cf5deadc-a965-4d1f-ae23-f3000b2883a8
# 12    43d0c840-96d9-4378-9c29-6d2a8899b1fe
# 13    09cfabf8-f348-4a58-918c-84e150c8a4fb
# 14    e0a70f6a-4a8e-4e2e-8d46-ab69d79f5747
# 15    72c5ffa4-e33d-4231-b073-6d8c2ca6b23b
# 16    01fc0c80-4780-43c8-895c-a48c93cb05d7
# 17    766177d5-6a2f-4a7d-b664-e7a84e3c1585
# 18    7b80e75d-397b-4011-9927-54dc35b422c1
# 19    ed948305-0670-4c13-b852-c10e2cdc3429
# 20    1fcc0c3a-b1ca-4095-9d28-ac1d9721cb38
# ...

# %%
reivews_df_index = reivews_df.set_index(['course','lesson'])
reivews_df_index
# Out:
#                                                                             id  \
# course     lesson
# java-basic static-variable-and-method     f2e05937-ed94-4b6d-bb97-655692634ec2
#            static-variable-and-method     15eb22a1-2245-4aad-9ba7-97df39c84f38
#            static-variable-and-method     e17da92e-9603-46ca-8875-bb0e2b947aeb
#            data-types                     96b4e922-b21b-49a0-8db5-32c3ddf34ecf
#            operators                      b31c6eef-6585-446a-be66-30a96ba8b77c
#            control-flow                   a1ef1419-ca84-4b0f-b1dc-4c14a6678d26
#            data-types                     8737810a-2147-4c54-9ccb-6e43f9eeefbc
#            object-orientation-basics      b2e95359-7897-4579-bfc6-04d18079ecbb
#            collection                     c84b4dc1-518b-45f9-9149-ed51402584b0
#            object-orientation-basics      cdfa19dc-ad50-45c6-be3c-bafd916f9de4
#            static-variable-and-method     b0703312-3de9-43af-b2dd-f7f1ebc638bf
# ...

# %%
reivews_df_index.loc[('java-basic','static-variable-and-method')]
# Out:
# c:\program files\python36\lib\site-packages\ipykernel_launcher.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   """Entry point for launching an IPython kernel.
#                                                                          id  \
# course     lesson
# java-basic static-variable-and-method  f2e05937-ed94-4b6d-bb97-655692634ec2
#            static-variable-and-method  15eb22a1-2245-4aad-9ba7-97df39c84f38
#            static-variable-and-method  e17da92e-9603-46ca-8875-bb0e2b947aeb
#            static-variable-and-method  b0703312-3de9-43af-b2dd-f7f1ebc638bf
#            static-variable-and-method  64c0460d-7aaf-43ee-8a1e-c2dd512e369d
#            static-variable-and-method  3d5db335-b7a0-45c3-8ccd-6956ae402ae4
#            static-variable-and-method  9602df60-f420-4677-b35e-b2e5c61391d6
#            static-variable-and-method  2b4e0216-bab7-4bdc-b116-fc094a8a333f
#            static-variable-and-method  74453dff-8d47-443b-8415-b28a82536a5e
# ...

# %%
reivews_df.groupby(['course','lesson']).min()
# Out:
#                                                                             id  \
# course     lesson
# java-basic abstract-class-and-interface   01fc0c80-4780-43c8-895c-a48c93cb05d7
#            blog-sample                    00350086-0d27-4d15-9619-2f02f88ea4f1
#            class                          01ebd08c-e4b2-4352-8b75-03d595872e7d
#            collection                     025f54b5-8025-4d10-92ac-3ec8519163fb
#            control-flow                   002c2033-311b-4118-bbf1-d93f456dfa52
#            data-types                     00078c4a-3baa-497a-b6f8-16b60c62ccfb
#            date                           0194aac2-6179-42b3-910d-610f456a2956
#            encapsulation-and-inheritance  012c3bdd-7a9b-4a04-b288-df94d5fd139c
#            exception                      0468177d-965c-442f-bd41-35afe9dc24dc
#            generic-basic                  08efe277-aff8-446a-aff3-d79a4c77645f
#            io                             0357556c-0ec9-4533-a548-440baa1d1047
# ...
