# %%
import pandas as pd

# %%
lesson_qa = pd.read_csv('./data/lesson_qa.csv')
lesson_qa
# Out:
#                                      q_id  \
# 0    26175486-1e0a-49bb-9078-0b9c329e8f31
# 1    82f0aaf4-a664-4329-828e-325618c446ff
# 2    e562139d-3585-40c5-9223-1ae7a3d9fc6b
# 3    3775bab5-e33b-4e8a-b8b8-9785755b849a
# 4                                      -1
# 5    f1ed9b01-1bcb-4b72-b857-844d3b9ad2c0
# 6    8e09eaff-913c-4dbd-9034-8fe4e9c0e3d5
# 7    1c60a3c5-ca61-4320-9d52-1a76dc8b8032
# 8    de5494a1-b0de-41f0-98c5-a99368a4a1e3
# 9    c0a17d8d-e7e5-48e3-8eab-c63850579164
# 10   1354de2c-5336-447c-97a9-25e592711ed5
# 11   eb8e1310-64d7-4d0c-936b-cb4238c9ce98
# 12   eb8e1310-64d7-4d0c-936b-cb4238c9ce98
# 13                                     -1
# 14   11f98a50-635d-4dbe-ab60-1d9fdda3bbc8
# 15   a8066b26-245e-4be5-8f05-a7b249757530
# 16   73d9f0cf-8820-451e-a648-859003718108
# 17   ddd414bd-31dc-4135-87cd-d7da98e7b008
# 18   c9402502-94d6-4288-b849-3109e5028f13
# 19   5fac91d9-e75c-46a2-929a-7be7295b7f6a
# 20   0fcb7c83-1d98-4359-a555-e273f7af03df
# ...

# %%
lesson_qa[lesson_qa.q_id != '-1']
# Out:
#                                      q_id  \
# 0    26175486-1e0a-49bb-9078-0b9c329e8f31
# 1    82f0aaf4-a664-4329-828e-325618c446ff
# 2    e562139d-3585-40c5-9223-1ae7a3d9fc6b
# 3    3775bab5-e33b-4e8a-b8b8-9785755b849a
# 5    f1ed9b01-1bcb-4b72-b857-844d3b9ad2c0
# 6    8e09eaff-913c-4dbd-9034-8fe4e9c0e3d5
# 7    1c60a3c5-ca61-4320-9d52-1a76dc8b8032
# 8    de5494a1-b0de-41f0-98c5-a99368a4a1e3
# 9    c0a17d8d-e7e5-48e3-8eab-c63850579164
# 10   1354de2c-5336-447c-97a9-25e592711ed5
# 11   eb8e1310-64d7-4d0c-936b-cb4238c9ce98
# 12   eb8e1310-64d7-4d0c-936b-cb4238c9ce98
# 14   11f98a50-635d-4dbe-ab60-1d9fdda3bbc8
# 15   a8066b26-245e-4be5-8f05-a7b249757530
# 16   73d9f0cf-8820-451e-a648-859003718108
# 17   ddd414bd-31dc-4135-87cd-d7da98e7b008
# 18   c9402502-94d6-4288-b849-3109e5028f13
# 19   5fac91d9-e75c-46a2-929a-7be7295b7f6a
# 20   0fcb7c83-1d98-4359-a555-e273f7af03df
# 21   dffef8b0-20ff-43b1-9727-c142d5017867
# 22   13bd53a5-027c-42e7-a7ba-e1f69ebfd49a
# ...

# %%
code_qa = pd.read_csv('./data/code_qa.csv')
code_qa.iloc[:,:100]
# Out:
#                                      q_id  \
# 0    bc718482-38fe-44e7-a2f4-b13f051fb73e
# 1    9af9759a-fe75-472e-86f5-a408b7c35c67
# 2    82573020-546f-4009-b41d-ec3d3d2ada03
# 3    8ac23f9b-aec1-428e-a5f3-74512c04c28b
# 4    d7b2e39b-37af-4ab9-b023-10747e3fd491
# 5    be1a6064-490b-4d9a-ae20-f0198e3386c6
# 6    fce3b739-c396-4cbe-8209-863ee8872ac2
# 7    d7ad2308-dc12-4810-81e4-92c1f3cb5e49
# 8    747300c0-a14b-4dd9-9484-d591b654c996
# 9    ac0c41b2-4da1-4279-a323-86a20dce55a9
# 10   ddcca42f-1edd-4019-9fd4-d9b2a8cfa1f6
# 11   0a8b0550-19f5-418e-b242-a890a412b6d2
# 12   a4faf2cc-f283-4a08-b1ee-c860ef5120ae
# 13   9fbd58ed-07bb-4696-b1d7-56ee3f621d67
# 14   be80c9a2-396b-4831-b2f0-88d2b7645f55
# 15   b2c869c5-bd7b-48ab-89bb-d8861af49bf0
# 16   934213db-6e48-4c1a-9eef-040e6951f8c6
# 17   e3018e36-2503-4f10-b996-08622cc006b4
# 18   59e6ac68-a8ab-4388-8002-bf3baee0a17c
# 19   faf176f2-b0c8-41ba-8e5f-2ebd1d7da561
# 20   63d81768-42fb-4ff8-90aa-e797624c43ff
# ...

# %%
code_qa.iloc[:100,2:]
# Out:
#                                                     q  \
# 0   <p>为什么在第15行有写 break ，而之后的 17、19、21、23、25 行都没有写...
# 1     <p>所以是在后面的17、19这些行里面也是应该写上&nbsp; break 的对吧？</p>
# 2                           <p>好的，已经修改，还是无法通过，求批改</p>
# 3                           <p>明白，已经改成两个了，但还是无法通过</p>
# 4                                      <p>谢谢，已经解决</p>
# 5                                  <p>请问应该怎么交换索引？</p>
# 6   <p><a>&nbsp;根据Title对数组进行升序排序[点击查看详情]</a></p><p...
# 7   <p><a>&nbsp;根据Title对数组进行升序排序 这一步怎么做？没明白..</a><...
# 8   <p><img alt="image.png" src="https://pic1.tian...
# 9                   <p>我是不是需要先定义一个数组，然后在把id放进数组里?</p>
# 10  <p>怎么能把id值输入进去呢？是不是应该先把id值放进数组里？我现在只会对post比较，不...
# 11                  <p>这里为什么会错误呢，还是需要用intValue函数呢</p>
# 12  <p>&nbsp;this.id = id;</p><p>&nbsp; &nbsp; &nb...
# 13                        <p>奇怪了，现在就是在if 中break 的</p>
# 14                  <p>一直显示没有加.后面的空格，所以有错，不知道该怎么改</p>
# 15    <p>SIZE 和LENGTH 怎么区分的呢。LENGTH一般表示的是什么，SIZE呢</p>
# ...

# %%
候选答案选取
